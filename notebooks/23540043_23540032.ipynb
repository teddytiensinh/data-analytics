# %% [markdown]
# <a href="https://colab.research.google.com/github/teddytiensinh/data-analytics/blob/main/23540043_23540032.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

DATA_URL = "https://raw.githubusercontent.com/teddytiensinh/data-analytics/main/datasets/StudentPerformance.csv"

df = pd.read_csv(DATA_URL)

df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0      20.133780   87.748828                  NaN                High
# 1      20.318256   64.878034                  Low              Medium
# 2      24.705809   98.103899               Medium              Medium
# 3      28.164164   92.454342                  Low              Medium
# 4      20.408266   95.706999               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No     6.818565        64.164329              Low
# 1                         No     8.539798       165.163758              Low
# 2                        Yes     6.750286        88.150310           Medium
# 3                        Yes     8.519461        97.548916           Medium
# 4                        Yes          NaN        63.039775           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...
